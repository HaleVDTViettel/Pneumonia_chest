# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

# %%
def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("basic")
pprint.pprint(configs)
# Out:
# {'albumentations': False,
#  'augmentations': False,
#  'balance': False,
#  'basic': True,
#  'batch_size': 128,
#  'cropping': False,
#  'fc1_size': 512,
#  'image_size': 56,
#  'lr': 0.001,
#  'model': 'fc',
#  'num_epochs': 3,
#  'scheduler': '',
#  'use_best_checkpoint': False}

# %%
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# ===============================================
# Running solution 1/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': True,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# 2024-03-12 22:40:58.312411: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-12 22:40:58.312433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-12 22:40:58.312967: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.2861, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2182, Train Loss = 0.8025, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.1833, Train Loss = 0.2360, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8552, Acc= 0.7975
# F1 = 0.86, accuracy = 0.80
# ===============================================
# Running solution 2/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': True,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.2782, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.3360, Train Loss = 0.8036, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.1688, Train Loss = 0.2591, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8328, Acc= 0.7576
# F1 = 0.83, accuracy = 0.76
# ===============================================
# Running solution 3/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': True,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3761, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2791, Train Loss = 1.4424, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2266, Train Loss = 0.3457, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8549, Acc= 0.7991
# F1 = 0.85, accuracy = 0.80
# ===============================================
# Running solution 4/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': True,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3186, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.1891, Train Loss = 0.7638, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.1812, Train Loss = 0.2506, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8186, Acc= 0.7312
# F1 = 0.82, accuracy = 0.73
# ===============================================
# Running solution 5/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': True,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3251, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2430, Train Loss = 0.9423, Epoch Time: 0m 09s, Remaining Time: 0m 09s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2602, Train Loss = 0.2716, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8686, Acc= 0.8330
# F1 = 0.87, accuracy = 0.83
# Results
# F1: 84.6% (+-1.8%)
# Accuracy: 78.4% (+-3.5%)
# Time of one solution: 0m 27s
#  | 84.6% (+-1.8%) | 78.4% (+-3.5%) | 0m 27s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': True,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}

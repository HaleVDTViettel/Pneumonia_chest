# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("resnet34_10eps")
print(configs)

logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# {'num_epochs': 10, 'lr': 0.001, 'batch_size': 128, 'image_size': 224, 'fc1_size': 512, 'basic': False, 'cropping': False, 'augmentations': True, 'albumentations': False, 'balance': True, 'scheduler': '', 'model': 'resnet34', 'use_best_checkpoint': False}
# ===============================================
# Running solution 1/5
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /home/thanhha/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:03<00:00, 23.3MB/s]
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# 2024-03-13 13:30:47.576820: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 13:30:47.576840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 13:30:47.577378: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.4900, Train Loss not available, Epoch Time: 0m 21s, Remaining Time: 3m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.1070, Train Loss = 0.2740, Epoch Time: 0m 20s, Remaining Time: 2m 42s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.1104, Train Loss = 0.1443, Epoch Time: 0m 20s, Remaining Time: 2m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.3057, Train Loss = 0.1216, Epoch Time: 0m 20s, Remaining Time: 1m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1389, Train Loss = 0.0935, Epoch Time: 0m 20s, Remaining Time: 1m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.2160, Train Loss = 0.1064, Epoch Time: 0m 20s, Remaining Time: 1m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.4518, Train Loss = 0.0791, Epoch Time: 0m 19s, Remaining Time: 0m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.1784, Train Loss = 0.0787, Epoch Time: 0m 19s, Remaining Time: 0m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1441, Train Loss = 0.1373, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.4715, Train Loss = 0.1822, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9191, Acc= 0.9036
# F1 = 0.92, accuracy = 0.90
# ===============================================
# Running solution 2/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.3693, Train Loss not available, Epoch Time: 0m 21s, Remaining Time: 3m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.2443, Train Loss = 0.2392, Epoch Time: 0m 20s, Remaining Time: 2m 41s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.3205, Train Loss = 0.1131, Epoch Time: 0m 20s, Remaining Time: 2m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.2397, Train Loss = 0.0861, Epoch Time: 0m 20s, Remaining Time: 1m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.3659, Train Loss = 0.0805, Epoch Time: 0m 20s, Remaining Time: 1m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.3657, Train Loss = 0.0868, Epoch Time: 0m 19s, Remaining Time: 1m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.0902, Train Loss = 0.0671, Epoch Time: 0m 19s, Remaining Time: 0m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.4439, Train Loss = 0.0687, Epoch Time: 0m 19s, Remaining Time: 0m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.2773, Train Loss = 0.0741, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.2560, Train Loss = 0.0625, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9292, Acc= 0.9125
# F1 = 0.93, accuracy = 0.91
# ===============================================
# Running solution 3/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.3525, Train Loss not available, Epoch Time: 0m 21s, Remaining Time: 3m 07s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.1468, Train Loss = 0.2400, Epoch Time: 0m 20s, Remaining Time: 2m 41s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.7872, Train Loss = 0.1183, Epoch Time: 0m 20s, Remaining Time: 2m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.3840, Train Loss = 0.1055, Epoch Time: 0m 20s, Remaining Time: 1m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1084, Train Loss = 0.0861, Epoch Time: 0m 19s, Remaining Time: 1m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.3238, Train Loss = 0.0881, Epoch Time: 0m 19s, Remaining Time: 1m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.0818, Train Loss = 0.0662, Epoch Time: 0m 19s, Remaining Time: 0m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.1918, Train Loss = 0.0940, Epoch Time: 0m 19s, Remaining Time: 0m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1539, Train Loss = 0.0744, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.3278, Train Loss = 0.0604, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9211, Acc= 0.9009
# F1 = 0.92, accuracy = 0.90
# ===============================================
# Running solution 4/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 1.0543, Train Loss not available, Epoch Time: 0m 21s, Remaining Time: 3m 06s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.5940, Train Loss = 0.2588, Epoch Time: 0m 20s, Remaining Time: 2m 40s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.5888, Train Loss = 0.1108, Epoch Time: 0m 20s, Remaining Time: 2m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.1364, Train Loss = 0.1057, Epoch Time: 0m 20s, Remaining Time: 1m 57s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1560, Train Loss = 0.1052, Epoch Time: 0m 19s, Remaining Time: 1m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.5157, Train Loss = 0.1000, Epoch Time: 0m 19s, Remaining Time: 1m 17s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.1198, Train Loss = 0.0889, Epoch Time: 0m 19s, Remaining Time: 0m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.2723, Train Loss = 0.0738, Epoch Time: 0m 19s, Remaining Time: 0m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1551, Train Loss = 0.0653, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.0802, Train Loss = 0.0658, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9065, Acc= 0.8761
# F1 = 0.91, accuracy = 0.88
# ===============================================
# Running solution 5/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.8349, Train Loss not available, Epoch Time: 0m 21s, Remaining Time: 3m 09s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.5823, Train Loss = 0.2394, Epoch Time: 0m 20s, Remaining Time: 2m 42s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.2513, Train Loss = 0.1118, Epoch Time: 0m 20s, Remaining Time: 2m 20s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.0997, Train Loss = 0.1016, Epoch Time: 0m 20s, Remaining Time: 1m 59s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.0661, Train Loss = 0.0935, Epoch Time: 0m 20s, Remaining Time: 1m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.2593, Train Loss = 0.0815, Epoch Time: 0m 20s, Remaining Time: 1m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.3047, Train Loss = 0.0707, Epoch Time: 0m 20s, Remaining Time: 0m 59s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.1466, Train Loss = 0.0635, Epoch Time: 0m 20s, Remaining Time: 0m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.0726, Train Loss = 0.0693, Epoch Time: 0m 20s, Remaining Time: 0m 20s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.2539, Train Loss = 0.0684, Epoch Time: 0m 20s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9445, Acc= 0.9313
# F1 = 0.94, accuracy = 0.93
# Results
# F1: 92.4% (+-1.3%)
# Accuracy: 90.5% (+-1.8%)
# Time of one solution: 3m 18s
#  | 92.4% (+-1.3%) | 90.5% (+-1.8%) | 3m 18s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}

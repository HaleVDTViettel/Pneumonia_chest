# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("augmented")
print(configs)

logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# {'num_epochs': 3, 'lr': 0.001, 'batch_size': 128, 'image_size': 56, 'fc1_size': 512, 'basic': False, 'cropping': False, 'augmentations': True, 'albumentations': False, 'balance': False, 'scheduler': '', 'model': 'fc', 'use_best_checkpoint': False}
# ===============================================
# Running solution 1/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# 2024-03-12 23:55:24.967304: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-12 23:55:24.967324: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-12 23:55:24.967841: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3543, Train Loss not available, Epoch Time: 0m 11s, Remaining Time: 0m 21s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2982, Train Loss = 1.0874, Epoch Time: 0m 10s, Remaining Time: 0m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2356, Train Loss = 0.3909, Epoch Time: 0m 09s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8778, Acc= 0.8422
# F1 = 0.88, accuracy = 0.84
# ===============================================
# Running solution 2/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3752, Train Loss not available, Epoch Time: 0m 10s, Remaining Time: 0m 20s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2735, Train Loss = 0.9459, Epoch Time: 0m 10s, Remaining Time: 0m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2286, Train Loss = 0.3862, Epoch Time: 0m 09s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8612, Acc= 0.8170
# F1 = 0.86, accuracy = 0.82
# ===============================================
# Running solution 3/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3486, Train Loss not available, Epoch Time: 0m 10s, Remaining Time: 0m 21s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2329, Train Loss = 1.0276, Epoch Time: 0m 10s, Remaining Time: 0m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2536, Train Loss = 0.3689, Epoch Time: 0m 09s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8551, Acc= 0.8116
# F1 = 0.86, accuracy = 0.81
# ===============================================
# Running solution 4/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3704, Train Loss not available, Epoch Time: 0m 11s, Remaining Time: 0m 21s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.3051, Train Loss = 1.0639, Epoch Time: 0m 10s, Remaining Time: 0m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.3119, Train Loss = 0.3643, Epoch Time: 0m 10s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8779, Acc= 0.8475
# F1 = 0.88, accuracy = 0.85
# ===============================================
# Running solution 5/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3416, Train Loss not available, Epoch Time: 0m 10s, Remaining Time: 0m 20s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2761, Train Loss = 1.0740, Epoch Time: 0m 10s, Remaining Time: 0m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2688, Train Loss = 0.3798, Epoch Time: 0m 09s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8655, Acc= 0.8259
# F1 = 0.87, accuracy = 0.83
# Results
# F1: 86.7% (+-0.9%)
# Accuracy: 82.9% (+-1.4%)
# Time of one solution: 0m 31s
#  | 86.7% (+-0.9%) | 82.9% (+-1.4%) | 0m 31s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}

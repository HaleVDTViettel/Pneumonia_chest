# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("crop")
print(configs)

logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# {'num_epochs': 3, 'lr': 0.001, 'batch_size': 128, 'image_size': 56, 'fc1_size': 512, 'basic': False, 'cropping': True, 'augmentations': False, 'albumentations': False, 'balance': False, 'scheduler': '', 'model': 'fc', 'use_best_checkpoint': False}
# ===============================================
# Running solution 1/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': True,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# 2024-03-12 22:47:45.085272: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-12 22:47:45.085291: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-12 22:47:45.085828: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3992, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.3241, Train Loss = 1.2919, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2202, Train Loss = 0.2871, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8620, Acc= 0.8098
# F1 = 0.86, accuracy = 0.81
# ===============================================
# Running solution 2/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': True,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.2748, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.3742, Train Loss = 0.6455, Epoch Time: 0m 09s, Remaining Time: 0m 09s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.1610, Train Loss = 0.2073, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8403, Acc= 0.7714
# F1 = 0.84, accuracy = 0.77
# ===============================================
# Running solution 3/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': True,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.2187, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.1644, Train Loss = 0.6232, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.1405, Train Loss = 0.1974, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8312, Acc= 0.7558
# F1 = 0.83, accuracy = 0.76
# ===============================================
# Running solution 4/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': True,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3547, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2700, Train Loss = 1.2770, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2222, Train Loss = 0.3122, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8257, Acc= 0.7453
# F1 = 0.83, accuracy = 0.75
# ===============================================
# Running solution 5/5
# CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': True,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.3400, Train Loss not available, Epoch Time: 0m 09s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2323, Train Loss = 1.0702, Epoch Time: 0m 08s, Remaining Time: 0m 08s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.1837, Train Loss = 0.3065, Epoch Time: 0m 08s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8483, Acc= 0.7853
# F1 = 0.85, accuracy = 0.79
# Results
# F1: 84.1% (+-1.3%)
# Accuracy: 77.4% (+-2.3%)
# Time of one solution: 0m 27s
#  | 84.1% (+-1.3%) | 77.4% (+-2.3%) | 0m 27s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': False,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': True,
#     'fc1_size': 512,
#     'image_size': 56,
#     'lr': 0.001,
#     'model': 'fc',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}

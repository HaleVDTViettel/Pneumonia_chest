# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("balance_dataset_10eps")
print(configs)

logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# {'num_epochs': 10, 'lr': 0.001, 'batch_size': 128, 'image_size': 256, 'fc1_size': 512, 'basic': False, 'cropping': False, 'augmentations': True, 'albumentations': False, 'balance': True, 'scheduler': '', 'model': 'cnn', 'use_best_checkpoint': False}
# ===============================================
# Running solution 1/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 256,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# 2024-03-13 01:47:29.731012: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 01:47:29.731035: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 01:47:29.731571: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.3637, Train Loss not available, Epoch Time: 0m 24s, Remaining Time: 3m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.4318, Train Loss = 0.7619, Epoch Time: 0m 23s, Remaining Time: 3m 06s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 1.2143, Train Loss = 0.3694, Epoch Time: 0m 23s, Remaining Time: 2m 40s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.1865, Train Loss = 0.2877, Epoch Time: 0m 23s, Remaining Time: 2m 16s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1378, Train Loss = 0.2468, Epoch Time: 0m 23s, Remaining Time: 1m 53s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 1.1281, Train Loss = 0.2464, Epoch Time: 0m 23s, Remaining Time: 1m 30s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.3867, Train Loss = 0.2377, Epoch Time: 0m 22s, Remaining Time: 1m 07s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.2228, Train Loss = 0.2184, Epoch Time: 0m 22s, Remaining Time: 0m 45s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.3942, Train Loss = 0.2243, Epoch Time: 0m 22s, Remaining Time: 0m 22s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1429, Train Loss = 0.2318, Epoch Time: 0m 22s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8999, Acc= 0.8699
# F1 = 0.90, accuracy = 0.87
# ===============================================
# Running solution 2/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 256,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.4812, Train Loss not available, Epoch Time: 0m 23s, Remaining Time: 3m 31s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.3354, Train Loss = 0.6957, Epoch Time: 0m 23s, Remaining Time: 3m 03s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.9435, Train Loss = 0.3466, Epoch Time: 0m 23s, Remaining Time: 2m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 1.1718, Train Loss = 0.3006, Epoch Time: 0m 22s, Remaining Time: 2m 15s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.3820, Train Loss = 0.2300, Epoch Time: 0m 22s, Remaining Time: 1m 52s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.7345, Train Loss = 0.2409, Epoch Time: 0m 22s, Remaining Time: 1m 29s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.3131, Train Loss = 0.2397, Epoch Time: 0m 22s, Remaining Time: 1m 07s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.1484, Train Loss = 0.2211, Epoch Time: 0m 22s, Remaining Time: 0m 44s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.2975, Train Loss = 0.2390, Epoch Time: 0m 22s, Remaining Time: 0m 22s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 3.2290, Train Loss = 0.2164, Epoch Time: 0m 22s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.1686, Acc= 0.4230
# F1 = 0.17, accuracy = 0.42
# ===============================================
# Running solution 3/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 256,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.6130, Train Loss not available, Epoch Time: 0m 23s, Remaining Time: 3m 31s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.3180, Train Loss = 0.8330, Epoch Time: 0m 23s, Remaining Time: 3m 01s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.1989, Train Loss = 0.4464, Epoch Time: 0m 22s, Remaining Time: 2m 36s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.1566, Train Loss = 0.3284, Epoch Time: 0m 22s, Remaining Time: 2m 13s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1701, Train Loss = 0.2768, Epoch Time: 0m 22s, Remaining Time: 1m 51s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.3302, Train Loss = 0.2603, Epoch Time: 0m 22s, Remaining Time: 1m 28s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 1.1002, Train Loss = 0.2532, Epoch Time: 0m 22s, Remaining Time: 1m 06s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 1.3583, Train Loss = 0.2474, Epoch Time: 0m 22s, Remaining Time: 0m 44s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.4266, Train Loss = 0.2345, Epoch Time: 0m 22s, Remaining Time: 0m 22s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.3084, Train Loss = 0.2149, Epoch Time: 0m 22s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8790, Acc= 0.8567
# F1 = 0.88, accuracy = 0.86
# ===============================================
# Running solution 4/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 256,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.6240, Train Loss not available, Epoch Time: 0m 24s, Remaining Time: 3m 32s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.4816, Train Loss = 0.9727, Epoch Time: 0m 23s, Remaining Time: 3m 01s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.4050, Train Loss = 0.5951, Epoch Time: 0m 22s, Remaining Time: 2m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.2859, Train Loss = 0.4284, Epoch Time: 0m 22s, Remaining Time: 2m 14s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.3213, Train Loss = 0.3088, Epoch Time: 0m 22s, Remaining Time: 1m 51s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.2239, Train Loss = 0.2747, Epoch Time: 0m 22s, Remaining Time: 1m 29s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.2668, Train Loss = 0.2542, Epoch Time: 0m 22s, Remaining Time: 1m 06s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.5633, Train Loss = 0.2570, Epoch Time: 0m 22s, Remaining Time: 0m 44s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.2338, Train Loss = 0.2645, Epoch Time: 0m 22s, Remaining Time: 0m 22s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.5281, Train Loss = 0.2267, Epoch Time: 0m 22s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8302, Acc= 0.8103
# F1 = 0.83, accuracy = 0.81
# ===============================================
# Running solution 5/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 256,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.5044, Train Loss not available, Epoch Time: 0m 23s, Remaining Time: 3m 31s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.2890, Train Loss = 0.8334, Epoch Time: 0m 23s, Remaining Time: 3m 01s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.3076, Train Loss = 0.4190, Epoch Time: 0m 22s, Remaining Time: 2m 36s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.8836, Train Loss = 0.3582, Epoch Time: 0m 22s, Remaining Time: 2m 13s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.2072, Train Loss = 0.3031, Epoch Time: 0m 22s, Remaining Time: 1m 50s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 1.4527, Train Loss = 0.2754, Epoch Time: 0m 22s, Remaining Time: 1m 28s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.2379, Train Loss = 0.2459, Epoch Time: 0m 22s, Remaining Time: 1m 06s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.1974, Train Loss = 0.2307, Epoch Time: 0m 22s, Remaining Time: 0m 44s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.8418, Train Loss = 0.2222, Epoch Time: 0m 22s, Remaining Time: 0m 22s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1322, Train Loss = 0.2386, Epoch Time: 0m 22s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8873, Acc= 0.8496
# F1 = 0.89, accuracy = 0.85
# Results
# F1: 73.3% (+-28.3%)
# Accuracy: 76.2% (+-17.1%)
# Time of one solution: 3m 43s
#  | 73.3% (+-28.3%) | 76.2% (+-17.1%) | 3m 43s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 256,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}

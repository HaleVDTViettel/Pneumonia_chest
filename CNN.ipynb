# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("cnn")
print(configs)

logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# {'num_epochs': 3, 'lr': 0.001, 'batch_size': 128, 'image_size': 224, 'fc1_size': 512, 'basic': False, 'cropping': False, 'augmentations': True, 'albumentations': False, 'balance': False, 'scheduler': '', 'model': 'cnn', 'use_best_checkpoint': False}
# ===============================================
# Running solution 1/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# 2024-03-13 00:54:09.773276: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 00:54:09.773296: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 00:54:09.773824: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.4261, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 0m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2836, Train Loss = 0.7521, Epoch Time: 0m 18s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.3530, Train Loss = 0.3955, Epoch Time: 0m 18s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8516, Acc= 0.8254
# F1 = 0.85, accuracy = 0.83
# ===============================================
# Running solution 2/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.4649, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 0m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2959, Train Loss = 0.7295, Epoch Time: 0m 18s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.3200, Train Loss = 0.4235, Epoch Time: 0m 18s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8704, Acc= 0.8424
# F1 = 0.87, accuracy = 0.84
# ===============================================
# Running solution 3/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.4284, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 0m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2509, Train Loss = 0.8461, Epoch Time: 0m 18s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2033, Train Loss = 0.3685, Epoch Time: 0m 18s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8791, Acc= 0.8373
# F1 = 0.88, accuracy = 0.84
# ===============================================
# Running solution 4/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.4642, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 0m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.2991, Train Loss = 0.7572, Epoch Time: 0m 18s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.3177, Train Loss = 0.4141, Epoch Time: 0m 18s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8602, Acc= 0.8328
# F1 = 0.86, accuracy = 0.83
# ===============================================
# Running solution 5/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/3: Validation Loss = 0.4745, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 0m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/3: Validation Loss = 0.3337, Train Loss = 0.7003, Epoch Time: 0m 18s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/3: Validation Loss = 0.2605, Train Loss = 0.4019, Epoch Time: 0m 18s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8707, Acc= 0.8324
# F1 = 0.87, accuracy = 0.83
# Results
# F1: 86.6% (+-0.9%)
# Accuracy: 83.4% (+-0.6%)
# Time of one solution: 0m 56s
#  | 86.6% (+-0.9%) | 83.4% (+-0.6%) | 0m 56s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 3,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("lr_schedule_CosineAnnealingLR_10eps")
print(configs)

logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# {'num_epochs': 10, 'lr': 0.001, 'batch_size': 128, 'image_size': 224, 'fc1_size': 512, 'basic': False, 'cropping': False, 'augmentations': True, 'albumentations': False, 'balance': True, 'scheduler': 'CosineAnnealingLR10', 'model': 'resnet34', 'use_best_checkpoint': False}
# ===============================================
# Running solution 1/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': 'CosineAnnealingLR10',
#     'use_best_checkpoint': False}
# 2024-03-13 15:03:50.823164: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 15:03:50.823191: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 15:03:50.823700: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.4895, Train Loss not available, Epoch Time: 0m 21s, Remaining Time: 3m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.3206, Train Loss = 0.2543, Epoch Time: 0m 20s, Remaining Time: 2m 41s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.0971, Train Loss = 0.1207, Epoch Time: 0m 20s, Remaining Time: 2m 20s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.3410, Train Loss = 0.0932, Epoch Time: 0m 20s, Remaining Time: 1m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1876, Train Loss = 0.0983, Epoch Time: 0m 20s, Remaining Time: 1m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.1771, Train Loss = 0.0771, Epoch Time: 0m 19s, Remaining Time: 1m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.1126, Train Loss = 0.0649, Epoch Time: 0m 19s, Remaining Time: 0m 58s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.1268, Train Loss = 0.0506, Epoch Time: 0m 19s, Remaining Time: 0m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1486, Train Loss = 0.0441, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1427, Train Loss = 0.0419, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9695, Acc= 0.9623
# F1 = 0.97, accuracy = 0.96
# ===============================================
# Running solution 2/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': 'CosineAnnealingLR10',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 1.9716, Train Loss not available, Epoch Time: 0m 21s, Remaining Time: 3m 06s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.0685, Train Loss = 0.2392, Epoch Time: 0m 20s, Remaining Time: 2m 39s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.0826, Train Loss = 0.1000, Epoch Time: 0m 20s, Remaining Time: 2m 17s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.9114, Train Loss = 0.1165, Epoch Time: 0m 19s, Remaining Time: 1m 56s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.7298, Train Loss = 0.0852, Epoch Time: 0m 19s, Remaining Time: 1m 36s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.1484, Train Loss = 0.0714, Epoch Time: 0m 19s, Remaining Time: 1m 17s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.2938, Train Loss = 0.0565, Epoch Time: 0m 19s, Remaining Time: 0m 57s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.3222, Train Loss = 0.0623, Epoch Time: 0m 19s, Remaining Time: 0m 38s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1736, Train Loss = 0.0347, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1507, Train Loss = 0.0335, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9621, Acc= 0.9525
# F1 = 0.96, accuracy = 0.95
# ===============================================
# Running solution 3/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': 'CosineAnnealingLR10',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 5.2717, Train Loss not available, Epoch Time: 0m 20s, Remaining Time: 2m 57s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.0843, Train Loss = 0.2705, Epoch Time: 0m 19s, Remaining Time: 2m 33s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.3112, Train Loss = 0.1123, Epoch Time: 0m 19s, Remaining Time: 2m 12s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.4139, Train Loss = 0.1136, Epoch Time: 0m 19s, Remaining Time: 1m 53s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1001, Train Loss = 0.0794, Epoch Time: 0m 19s, Remaining Time: 1m 33s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.1492, Train Loss = 0.0756, Epoch Time: 0m 19s, Remaining Time: 1m 14s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.0889, Train Loss = 0.0586, Epoch Time: 0m 18s, Remaining Time: 0m 55s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.2640, Train Loss = 0.0529, Epoch Time: 0m 18s, Remaining Time: 0m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1635, Train Loss = 0.0456, Epoch Time: 0m 18s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.0911, Train Loss = 0.0438, Epoch Time: 0m 18s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9651, Acc= 0.9560
# F1 = 0.97, accuracy = 0.96
# ===============================================
# Running solution 4/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': 'CosineAnnealingLR10',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.3872, Train Loss not available, Epoch Time: 0m 20s, Remaining Time: 3m 01s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.3615, Train Loss = 0.2410, Epoch Time: 0m 19s, Remaining Time: 2m 34s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.2437, Train Loss = 0.1208, Epoch Time: 0m 19s, Remaining Time: 2m 14s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.1038, Train Loss = 0.0956, Epoch Time: 0m 19s, Remaining Time: 1m 54s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.0722, Train Loss = 0.0815, Epoch Time: 0m 19s, Remaining Time: 1m 35s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.1537, Train Loss = 0.0968, Epoch Time: 0m 19s, Remaining Time: 1m 16s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.1233, Train Loss = 0.0674, Epoch Time: 0m 19s, Remaining Time: 0m 56s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.0648, Train Loss = 0.0588, Epoch Time: 0m 19s, Remaining Time: 0m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1923, Train Loss = 0.0412, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1010, Train Loss = 0.0478, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9646, Acc= 0.9558
# F1 = 0.96, accuracy = 0.96
# ===============================================
# Running solution 5/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': 'CosineAnnealingLR10',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 1.5485, Train Loss not available, Epoch Time: 0m 20s, Remaining Time: 2m 60s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.3110, Train Loss = 0.2570, Epoch Time: 0m 19s, Remaining Time: 2m 34s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.0650, Train Loss = 0.1415, Epoch Time: 0m 19s, Remaining Time: 2m 13s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.0716, Train Loss = 0.0878, Epoch Time: 0m 19s, Remaining Time: 1m 54s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.0499, Train Loss = 0.0839, Epoch Time: 0m 19s, Remaining Time: 1m 34s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.2113, Train Loss = 0.0872, Epoch Time: 0m 19s, Remaining Time: 1m 15s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.0649, Train Loss = 0.0655, Epoch Time: 0m 19s, Remaining Time: 0m 56s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.1806, Train Loss = 0.0501, Epoch Time: 0m 19s, Remaining Time: 0m 37s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.0583, Train Loss = 0.0564, Epoch Time: 0m 19s, Remaining Time: 0m 19s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1164, Train Loss = 0.0364, Epoch Time: 0m 19s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.9708, Acc= 0.9634
# F1 = 0.97, accuracy = 0.96
# Results
# F1: 96.6% (+-0.3%)
# Accuracy: 95.8% (+-0.4%)
# Time of one solution: 3m 11s
#  | 96.6% (+-0.3%) | 95.8% (+-0.4%) | 3m 11s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': True,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'resnet34',
#     'num_epochs': 10,
#     'scheduler': 'CosineAnnealingLR10',
#     'use_best_checkpoint': False}

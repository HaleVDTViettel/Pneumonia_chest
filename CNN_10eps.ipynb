# %%
import warnings
warnings.filterwarnings("ignore")

import time
import yaml
import pprint
import logging
import numpy as np
from modules.check_solution import *

def _get_configs(configs):
    with open(f"configs/{configs}.yaml", "r") as file:
        configs = yaml.safe_load(file)
    return configs

configs = _get_configs("cnn_10eps")
print(configs)

logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

f1_array = np.array([])
accuracy_array = np.array([])
start_time = time.time()

repeats = 5
for i in range(repeats):
    print("===============================================")
    print(f"Running solution {i+1}/{repeats}")
    f1, accuracy = check_solution(configs, verbose=(i==0))
    print(f"F1 = {f1:.2f}, accuracy = {accuracy:.2f} ")
    f1_array = np.append(f1_array, f1)
    accuracy_array = np.append(accuracy_array, accuracy) 

# Calculate elapsed time and remaining time
repeat_time = (time.time() - start_time) / repeats
repeat_time_min, repeat_time_sec = divmod(repeat_time, 60)

# Printing final results
print("Results")
print(f"F1: {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%})")
print(f"Accuracy: {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%})")
print(f"Time of one solution: {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")
print(f" | {np.mean(f1_array):.1%} (+-{np.std(f1_array):.1%}) | {np.mean(accuracy_array):.1%} (+-{np.std(accuracy_array):.1%}) | {repeat_time_min:.0f}m {repeat_time_sec:.0f}s")

# Print hyperparameters for reminding what the final data is for
print("Hyperparameters:")
pprint.pprint(configs, indent=4)
# Out:
# {'num_epochs': 10, 'lr': 0.001, 'batch_size': 128, 'image_size': 224, 'fc1_size': 512, 'basic': False, 'cropping': False, 'augmentations': True, 'albumentations': False, 'balance': False, 'scheduler': '', 'model': 'cnn', 'use_best_checkpoint': False}
# ===============================================
# Running solution 1/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# 2024-03-13 01:31:42.827203: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 01:31:42.827221: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 01:31:42.827733: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.4076, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 2m 54s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.2762, Train Loss = 0.6947, Epoch Time: 0m 19s, Remaining Time: 2m 28s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.2037, Train Loss = 0.3806, Epoch Time: 0m 18s, Remaining Time: 2m 07s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.2101, Train Loss = 0.2919, Epoch Time: 0m 18s, Remaining Time: 1m 48s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1898, Train Loss = 0.2864, Epoch Time: 0m 18s, Remaining Time: 1m 30s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.2110, Train Loss = 0.2254, Epoch Time: 0m 18s, Remaining Time: 1m 11s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.7356, Train Loss = 0.2124, Epoch Time: 0m 18s, Remaining Time: 0m 53s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.3591, Train Loss = 0.2164, Epoch Time: 0m 18s, Remaining Time: 0m 36s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.7488, Train Loss = 0.1999, Epoch Time: 0m 18s, Remaining Time: 0m 18s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.6543, Train Loss = 0.2016, Epoch Time: 0m 18s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.7716, Acc= 0.7580
# F1 = 0.77, accuracy = 0.76
# ===============================================
# Running solution 2/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.5218, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 2m 50s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.3155, Train Loss = 0.7464, Epoch Time: 0m 18s, Remaining Time: 2m 24s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.5663, Train Loss = 0.4494, Epoch Time: 0m 18s, Remaining Time: 2m 04s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.5482, Train Loss = 0.2991, Epoch Time: 0m 18s, Remaining Time: 1m 45s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1704, Train Loss = 0.2551, Epoch Time: 0m 17s, Remaining Time: 1m 27s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.8821, Train Loss = 0.2497, Epoch Time: 0m 17s, Remaining Time: 1m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.4797, Train Loss = 0.2379, Epoch Time: 0m 17s, Remaining Time: 0m 52s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.3598, Train Loss = 0.2247, Epoch Time: 0m 17s, Remaining Time: 0m 35s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.3780, Train Loss = 0.2115, Epoch Time: 0m 17s, Remaining Time: 0m 17s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1279, Train Loss = 0.2239, Epoch Time: 0m 17s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8795, Acc= 0.8384
# F1 = 0.88, accuracy = 0.84
# ===============================================
# Running solution 3/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.3481, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 2m 52s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.2175, Train Loss = 0.6707, Epoch Time: 0m 18s, Remaining Time: 2m 26s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.1832, Train Loss = 0.3603, Epoch Time: 0m 18s, Remaining Time: 2m 05s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.1468, Train Loss = 0.3106, Epoch Time: 0m 18s, Remaining Time: 1m 46s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1443, Train Loss = 0.2832, Epoch Time: 0m 18s, Remaining Time: 1m 28s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.1390, Train Loss = 0.2480, Epoch Time: 0m 17s, Remaining Time: 1m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.1400, Train Loss = 0.2243, Epoch Time: 0m 17s, Remaining Time: 0m 52s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.2101, Train Loss = 0.2090, Epoch Time: 0m 17s, Remaining Time: 0m 35s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.1477, Train Loss = 0.2226, Epoch Time: 0m 17s, Remaining Time: 0m 17s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1206, Train Loss = 0.2045, Epoch Time: 0m 17s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8693, Acc= 0.8172
# F1 = 0.87, accuracy = 0.82
# ===============================================
# Running solution 4/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.2688, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 2m 52s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.2466, Train Loss = 0.5585, Epoch Time: 0m 18s, Remaining Time: 2m 25s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.1529, Train Loss = 0.2902, Epoch Time: 0m 18s, Remaining Time: 2m 05s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.1600, Train Loss = 0.2514, Epoch Time: 0m 18s, Remaining Time: 1m 46s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.6133, Train Loss = 0.2244, Epoch Time: 0m 18s, Remaining Time: 1m 28s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.2247, Train Loss = 0.2077, Epoch Time: 0m 18s, Remaining Time: 1m 10s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.2478, Train Loss = 0.1969, Epoch Time: 0m 17s, Remaining Time: 0m 52s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.3727, Train Loss = 0.1890, Epoch Time: 0m 17s, Remaining Time: 0m 35s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.5103, Train Loss = 0.1966, Epoch Time: 0m 17s, Remaining Time: 0m 17s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.3035, Train Loss = 0.1982, Epoch Time: 0m 17s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8832, Acc= 0.8609
# F1 = 0.88, accuracy = 0.86
# ===============================================
# Running solution 5/5
# 'CPU cores: 20 | Device: cuda | GPU: NVIDIA GeForce RTX 3090'
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 1/10: Validation Loss = 0.4874, Train Loss not available, Epoch Time: 0m 19s, Remaining Time: 2m 48s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 2/10: Validation Loss = 0.3123, Train Loss = 0.7808, Epoch Time: 0m 18s, Remaining Time: 2m 23s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 3/10: Validation Loss = 0.3036, Train Loss = 0.4215, Epoch Time: 0m 18s, Remaining Time: 2m 03s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4/10: Validation Loss = 0.1979, Train Loss = 0.3432, Epoch Time: 0m 17s, Remaining Time: 1m 45s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 5/10: Validation Loss = 0.1579, Train Loss = 0.2908, Epoch Time: 0m 17s, Remaining Time: 1m 27s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6/10: Validation Loss = 0.1903, Train Loss = 0.2410, Epoch Time: 0m 17s, Remaining Time: 1m 09s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7/10: Validation Loss = 0.1943, Train Loss = 0.2319, Epoch Time: 0m 17s, Remaining Time: 0m 52s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8/10: Validation Loss = 0.4424, Train Loss = 0.2140, Epoch Time: 0m 17s, Remaining Time: 0m 34s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9/10: Validation Loss = 0.3286, Train Loss = 0.2095, Epoch Time: 0m 17s, Remaining Time: 0m 17s
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 10/10: Validation Loss = 0.1480, Train Loss = 0.2052, Epoch Time: 0m 17s, Remaining Time: 0m 00s
# Testing: |          | 0/? [00:00<?, ?it/s]
# Best: F1= 0.8970, Acc= 0.8663
# F1 = 0.90, accuracy = 0.87
# Results
# F1: 86.0% (+-4.5%)
# Accuracy: 82.8% (+-3.9%)
# Time of one solution: 2m 57s
#  | 86.0% (+-4.5%) | 82.8% (+-3.9%) | 2m 57s
# Hyperparameters:
# {   'albumentations': False,
#     'augmentations': True,
#     'balance': False,
#     'basic': False,
#     'batch_size': 128,
#     'cropping': False,
#     'fc1_size': 512,
#     'image_size': 224,
#     'lr': 0.001,
#     'model': 'cnn',
#     'num_epochs': 10,
#     'scheduler': '',
#     'use_best_checkpoint': False}
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
